# %%
# Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
# Importing matplotlib to show graphical representation of the attributes
import matplotlib.pyplot as plt
# to ignore/remove warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [11], line 4
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import seaborn as sns
#       5 # Importing matplotlib to show graphical representation of the attributes
#       6 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df = pd.read_csv("JOB-PostData.csv")
df.head()
# Out:
#                                            link-href  \
# 0  https://uk.indeed.com/rc/clk?jk=f5433fbb63f273...
# 1  https://uk.indeed.com/rc/clk?jk=160e7785918180...
# 2  https://uk.indeed.com/company/British-Antarcti...
# 3  https://uk.indeed.com/rc/clk?jk=d90667d1f03b0c...
# 4  https://uk.indeed.com/rc/clk?jk=4c25007318fbe6...
#
#                                            job_title  \
# 0  Analyst, Quantitative Researcher - FX Systemat...
# 1                 Research Science Analyst - Finalta
# 2               Scientific Data Assistant (10 weeks)
# 3   Research Ecologist - Data analysis and modelling
# 4  Associate, Statistical Arbitrage Quantitative ...
#
#                     company_name  \
# 0                  Goldman Sachs
# 1             McKinsey & Company
# 2       British Antarctic Survey
# 3  British Trust for Ornithology
# 4                  Goldman Sachs
#
#                                          discription  \
# 0  GLOBAL MARKETS \n  Our core value is building ...
# 1  Who You'll Work With \n   \n    \n     You’ll ...
# 2  Background/Overview: \nBritish Antarctic Surve...
# 3  Research Ecologist- Population data analysis a...
# 4  Our core value is building strong relationship...
#
#                      salary job_type        date  python    sql      R   java  \
# 0                       NaN      NaN   month ago    True  False  False   True
# 1                       NaN      NaN   month ago   False  False  False  False
# 2       From £25,702 a year   #NAME?   month ago   False   True  False  False
# 3  £25,828 - £27,263 a year   #NAME?  27/10/2022   False  False   True  False
# 4                       NaN      NaN   month ago   False  False  False  False
#
#    javascript   html      C     C#    sas  Bachelors  Masters    Phd
# 0       False   True  False  False  False      False    False  False
# 1       False  False  False  False  False      False    False  False
# 2       False  False  False  False  False      False    False  False
# 3       False  False  False  False   True      False    False   True
# 4       False   True  False  False  False      False    False  False
